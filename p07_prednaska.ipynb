# %%
import numpy as np
import numpy.polynomial.polynomial as poly
import matplotlib.pyplot as plt
print(poly.polyval(3, np.array([1, 2, 3])))
print(poly.polyval(3, [1, 2, 3]))
hodnoty = poly.polyval([2.3, 1.1], [1, 2, 3])
print(type(hodnoty))
x = np.array([1, 2, 3, 4, 5])
y = np.array([1.2, 4.5, 3.2, 6.6, 3.5])
korene = poly.polyroots([1, 1, 1])
print(korene[0].imag)
print(np.iscomplex(korene))
# type(korene)
# plt.plot(x, y)
# plt.show()
# c = poly.polyfit(x, y, 1)
# print(c)
# print(poly.polyval(2.5, c))
# print(poly.polyint(c))
# print(poly.polyadd(c, c))
# q = poly.Polynomial(c)
# print(q)
# print(poly.polyval(2.5, q))
# plt.plot(x, y, 'rx', x, q(x))
# print(q(2.5))
# Out:
# 34.0
# 34.0
# <class 'numpy.ndarray'>
# -0.866025403784
# [ True  True]

# %%
c1 = [0.5, 1, 2.3]
c2 = [0, -1]
c3 = [1, 4, 5, -2]
c4 = [0, 0, 1]
print(polyadd())

# %%
p = poly.polyfromroots([-3, 1.5, 2.8])
print(p)

# %%
p = poly.polyfromroots([-1,0,1])
print(p)

# %%
i = complex(0,1)
p = poly.polyfromroots([-i, i])
print(p)

# %%
p = poly.polyder([1, 2, 3])
print(p)

# %%
stupen = 2
p = poly.polyder([4, 3, 2, 1], stupen)
print(p)

# %%
p = poly.polyint([1, 2, 3])
print(p)

# %%
stupen = 2
p = poly.polyint([0, 2, 0, 1], stupen)
print(p)

# %%
p1 = [1, 0, 3]; p2 = [-2, 1]
p = poly.polyadd(p1, p2)
print(p)

# %%
p = poly.polysub(p1, p2); print(p)

# %%
p = poly.polymul(p1, p2); print(p)

# %%
podiel, zvysok = poly.polydiv(p1, p2)
print(podiel)
print(zvysok)

# %%
stupen = 3
p = poly.polypow(p2, stupen)
print(p)

# %%
x = [10.0, 12.5, 25.8, 32.6]
y = np.array([980, 1010, 1284.5, 1400])
stupen = 2
p = poly.polyfit(x, y, stupen)
print(p)
plt.plot(x, y, 'x', x, poly.polyval(x, p), 'r')
plt.show()

# %%
p = poly.Polynomial([1, 2, 0, 3])
print(p)
p(2.5)
h = p([2.5, 4.6])
print(h)

# %%
d = p.degree()
print(p.roots())
print(p+p)

# %%
p1 = poly.Polynomial([1., 2, 0, 3]) # 1+2x+3x^3
p2 = poly.Polynomial([0., 1])       # x
s = p1+p2
print(s)
print(p1-p2)
print(p1*p2)
p,z=p1/p2
print(p, z)

# %%
koeficienty = [ -3.0, 0, 1.0 ]
rozsah = [-4.0, 5.5]
p = poly.Polynomial(koeficienty, rozsah)
q = poly.Polynomial(koeficienty)
x, y = p.linspace(10);
print(p(x))
xx,_ = p.linspace(10);
print(xx)

# %%
v = np.array([4.2, 1.8, 0.3, 3.2])
z = np.sort(v)
print(z, z[::-1], z, v)
i = np.argsort(v)
print(i)

# %%
v = np.array([4.2, 1.8, 0.3, 3.2])
print(np.max(v), np.min(v))

# %%
v = np.array([4.2, 0.0, -1.8, 4.2, 0.0])
imax = np.argmax(v)
imin = np.argmin(v)
inonzero = np.nonzero(v)
print(imax, imin)
print(inonzero)

# %%
data = np.loadtxt('05_aproximacia.txt', unpack=True)
print(data[1, :])

# %%
M = np.array([ [1., 2., 3.], [4., 5., 6.]])
np.savetxt('matica.txt', M)

# %%
f = open('matica.txt', 'r')
print(f.read())
f.close()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib as mp
x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)
xx, yy = np.meshgrid(x, y)
zz = np.sin(xx**2 + yy**2) / (xx**2 + yy**2)
# h = plt.contour(xx, yy, zz)

fig = plt.figure()
ax = fig.gca(projection='3d')
# h = ax.plot_surface(xx, yy, zz)
# ax.plot_surface(xx, yy, zz)
# ax.plot_wireframe(xx, yy, zz)
plt.plot(x, y, x*y+np.sin(x**2))

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-5, 5, 0.5)
y = np.arange(-5, 5, 0.5)
ax = plt.gca(projection='3d')
plt.plot(x, y, x*y+np.sin(x**2))
plt.plot(x, y, np.abs(x)+np.cos(y), 'rx')
plt.show()

# %%
zz = np.zeros(xx.shape)  # nulova matica
for i in range(xx.shape[0]):
    for j in range(xx.shape[1]):
        zz[i,j] = xx[i, j]*yy[i, j]
plt.contour(xx, yy, zz)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 1, 500)
y = np.sin(4 * np.pi * x) * np.exp(-5 * x)

plt.fill(x, y, color='r')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4])
y = x**2
kategorie = ['Jan', 'Feb', 'Mar', 'Apr']

plt.bar(x, y)
plt.grid(True)
plt.show()
plt.barh(x, y, color='g')
plt.grid(True)
plt.show()

# %%
x = np.array([1, 2, 3, 4, 1, 1, 2, 1, 3, 4, 4])
plt.hist(x, color='r')
plt.show()

# %%
x = [4, 8, 12, 3]
oznacenie = ['Jan', 'Feb', 'Mar', 'Apr']
plt.pie(x); plt.show()
kategorie = ['Jan', 'Feb', 'Mar', 'Apr']
explode = [0, 0.1, 0, 0]
plt.pie(x, labels=kategorie, explode=explode, 
           shadow=True, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
x = np.arange(-5, 5, 0.5)
y = np.arange(-5, 5, 0.5)
ax = plt.gca(projection='3d')
plt.plot(x, y, x*y+np.sin(x**2))
plt.savefig('obrazok.png')
